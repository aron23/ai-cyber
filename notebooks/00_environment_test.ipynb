# %%
# Environment Test Notebook
**Purpose**: Verify all required packages can be imported successfully  
**Created**: 15/06/2025  
**Task**: DE-001 Environment Setup

# %%
# Core Data Processing
import pandas as pd
import numpy as np
import scipy
print(f"✓ Pandas: {pd.__version__}")
print(f"✓ NumPy: {np.__version__}")
print(f"✓ SciPy: {scipy.__version__}")

# %%
# Machine Learning
import sklearn
import nltk
from textblob import TextBlob
print(f"✓ Scikit-learn: {sklearn.__version__}")
print(f"✓ NLTK: {nltk.__version__}")
print("✓ TextBlob: Available")

# %%
# Test Data Loading
import os
from datetime import datetime

data_path = '../data/SMSSPamCollection'
if os.path.exists(data_path):
    with open(data_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()
    print(f"✓ Dataset loaded: {len(lines)} messages")
    print(f"✓ First line preview: {lines[0][:50]}...")
else:
    print("❌ Dataset not found - checking data directory...")
    if os.path.exists('../data'):
        data_files = os.listdir('../data')
        print(f"Available data files: {data_files}")
    else:
        print("❌ Data directory not found")

print(f"\nTest completed: {datetime.now().strftime('%d/%m/%Y %H:%M:%S')}")
print("🎉 Environment Test Complete!")
